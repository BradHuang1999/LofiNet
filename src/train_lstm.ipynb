# %%
import glob
import pickle
import numpy as np
from numpy.testing import assert_allclose
import pandas as pd
from music21 import *
from keras.models import Sequential, load_model
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM, Bidirectional
from keras.layers import Activation
from keras.layers import BatchNormalization as BatchNorm
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
import tensorflow as tf
from pygame import *
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
#creating an empty list to hold the notes in
notes = []
midi_scores = []

#this for loop goes through each midi file and flattens out the notes inside of it
for file in glob.glob("../data/training_melody/*.mid"):
    print(f'processing {file}')
    
    midi = converter.parse(file)
    midi_scores.append(midi)
    
    notes_to_parse = midi.flat.notes    
        
    for element in notes_to_parse: 
        if isinstance(element, note.Note): #if it's a single note, we don't have to join it to any other notes in the series
            notes.append(str(element.pitch))
        elif isinstance(element, chord.Chord): #if it's a chord, we will have to join it to the other notes
            notes.append('.'.join(str(n) for n in element.normalOrder))
        else:
            print(element)
# Out:
# processing ../data/training_melody/ii-V9.mid
# processing ../data/training_melody/c19.mid
# processing ../data/training_melody/c25.mid
# processing ../data/training_melody/Loop 8 (Toogood) B.mid
# processing ../data/training_melody/c24.mid
# processing ../data/training_melody/c30.mid
# processing ../data/training_melody/c18.mid
# processing ../data/training_melody/ii-V8.mid
# processing ../data/training_melody/lofitrack_14_melody.mid
# processing ../data/training_melody/lofitrack_3_melody.mid
# processing ../data/training_melody/c9.mid
# processing ../data/training_melody/c26.mid
# processing ../data/training_melody/Loop 8 (Toogood) A.mid
# processing ../data/training_melody/Loop 5 (Away With You).mid
# processing ../data/training_melody/c27.mid
# processing ../data/training_melody/c8.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 11 - A Maj.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 7 - E Min.mid
# processing ../data/training_melody/tree9.mid
# processing ../data/training_melody/c23.mid
# processing ../data/training_melody/c22.mid
# processing ../data/training_melody/tree8.mid
# processing ../data/training_melody/Loop 2 (Piele) A.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 3 - D Maj.mid
# processing ../data/training_melody/c20.mid
# processing ../data/training_melody/lofitrack_11_melody.mid
# processing ../data/training_melody/c21.mid
# processing ../data/training_melody/lofitrack_6_melody.mid
# processing ../data/training_melody/Loop 2 (Piele) B.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 15 - A# Maj.mid
# processing ../data/training_melody/blob17.mid
# processing ../data/training_melody/reece7.mid
# processing ../data/training_melody/blob3.mid
# processing ../data/training_melody/reece20.mid
# processing ../data/training_melody/midi 8.mid
# processing ../data/training_melody/lofitrack_1_melody.mid
# processing ../data/training_melody/ii-V11.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 18 - A# Maj.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 22 - B Min.mid
# processing ../data/training_melody/ii-V10.mid
# processing ../data/training_melody/midi 9.mid
# processing ../data/training_melody/blob2.mid
# processing ../data/training_melody/reece21.mid
# processing ../data/training_melody/reece6.mid
# processing ../data/training_melody/blob16.mid
# processing ../data/training_melody/blob14.mid
# processing ../data/training_melody/reece4.mid
# processing ../data/training_melody/ii-V12.mid
# processing ../data/training_melody/tree21.mid
# processing ../data/training_melody/tree20.mid
# processing ../data/training_melody/ii-V13.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 20 - A# Min.mid
# processing ../data/training_melody/reece22.mid
# processing ../data/training_melody/blob1.mid
# processing ../data/training_melody/reece5.mid
# processing ../data/training_melody/blob15.mid
# processing ../data/training_melody/Loop 3 (With You).mid
# processing ../data/training_melody/blob11.mid
# processing ../data/training_melody/reece1.mid
# processing ../data/training_melody/blob5.mid
# processing ../data/training_melody/lofitrack_9_melody.mid
# processing ../data/training_melody/ii-V17.mid
# processing ../data/training_melody/tree18.mid
# processing ../data/training_melody/tree19.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 13 - A Min.mid
# processing ../data/training_melody/ii-V16.mid
# processing ../data/training_melody/blob4.mid
# processing ../data/training_melody/blob10.mid
# processing ../data/training_melody/lofitrack_13_melody.mid
# processing ../data/training_melody/LofiPianoSample9.mid
# processing ../data/training_melody/blob12.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 21 - A# Min.mid
# processing ../data/training_melody/lofitrack_4_melody.mid
# processing ../data/training_melody/reece2.mid
# processing ../data/training_melody/blob6.mid
# processing ../data/training_melody/reece19.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 1 - C Maj.mid
# processing ../data/training_melody/ii-V14.mid
# processing ../data/training_melody/ii-V15.mid
# processing ../data/training_melody/reece18.mid
# processing ../data/training_melody/blob7.mid
# processing ../data/training_melody/reece3.mid
# processing ../data/training_melody/blob13.mid
# processing ../data/training_melody/LofiPianoSample8.mid
# processing ../data/training_melody/LofiPianoSample5.mid
# processing ../data/training_melody/blob22.mid
# processing ../data/training_melody/Loop 1 (Down Here) B.mid
# processing ../data/training_melody/reece15.mid
# processing ../data/training_melody/ii-V18.mid
# processing ../data/training_melody/midi 11.mid
# processing ../data/training_melody/tree17.mid
# processing ../data/training_melody/tree16.mid
# processing ../data/training_melody/midi 10.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 10 - F Min.mid
# processing ../data/training_melody/ii-V19.mid
# processing ../data/training_melody/reece14.mid
# processing ../data/training_melody/blob23.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 2 - C# Min.mid
# processing ../data/training_melody/LofiPianoSample4.mid
# processing ../data/training_melody/LofiPianoSample6.mid
# processing ../data/training_melody/blob21.mid
# processing ../data/training_melody/Loop 1 (Down Here) A.mid
# processing ../data/training_melody/blob9.mid
# processing ../data/training_melody/reece16.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 9 - F Min.mid
# processing ../data/training_melody/Midi 2.mid
# processing ../data/training_melody/tree14.mid
# processing ../data/training_melody/midi 12.mid
# processing ../data/training_melody/midi 13.mid
# processing ../data/training_melody/tree15.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 14 - A Min.mid
# processing ../data/training_melody/midi 3.mid
# processing ../data/training_melody/reece17.mid
# processing ../data/training_melody/blob8.mid
# processing ../data/training_melody/lofitrack_10_melody.mid
# processing ../data/training_melody/blob20.mid
# processing ../data/training_melody/LofiPianoSample7.mid
# processing ../data/training_melody/lofitrack_7_melody.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 8 - F Maj.mid
# processing ../data/training_melody/LofiPianoSample3.mid
# processing ../data/training_melody/blob18.mid
# processing ../data/training_melody/blob24.mid
# processing ../data/training_melody/PianoMiniature.mid
# processing ../data/training_melody/reece8.mid
# processing ../data/training_melody/Loop 6 (Musella) B.mid
# processing ../data/training_melody/reece13.mid
# processing ../data/training_melody/midi 7.mid
# processing ../data/training_melody/ii-V22.mid
# processing ../data/training_melody/tree11.mid
# processing ../data/training_melody/midi 16.mid
# processing ../data/training_melody/tree10.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 6 - D Min.mid
# processing ../data/training_melody/lofitrack_15_melody.mid
# processing ../data/training_melody/ii-V23.mid
# processing ../data/training_melody/midi 6.mid
# processing ../data/training_melody/lofitrack_2_melody.mid
# processing ../data/training_melody/reece12.mid
# processing ../data/training_melody/reece9.mid
# processing ../data/training_melody/blob19.mid
# processing ../data/training_melody/LofiPianoSample2.mid
# processing ../data/training_melody/Loop 6 (Musella) A.mid
# processing ../data/training_melody/reece10.mid
# processing ../data/training_melody/midi 4.mid
# processing ../data/training_melody/ii-V21.mid
# processing ../data/training_melody/midi 14.mid
# processing ../data/training_melody/tree12.mid
# processing ../data/training_melody/tree13.mid
# processing ../data/training_melody/midi 15.mid
# processing ../data/training_melody/ii-V20.mid
# processing ../data/training_melody/midi 5.mid
# processing ../data/training_melody/reece11.mid
# processing ../data/training_melody/Loop 7 (Runaway) A.mid
# processing ../data/training_melody/LofiPianoSample1.mid
# processing ../data/training_melody/lofitrack_8_melody.mid
# processing ../data/training_melody/c3.mid
# processing ../data/training_melody/tree6.mid
# processing ../data/training_melody/c10.mid
# processing ../data/training_melody/c11.mid
# processing ../data/training_melody/Loop 6 (Runaway) B.mid
# processing ../data/training_melody/tree7.mid
# processing ../data/training_melody/c2.mid
# processing ../data/training_melody/ii-V1.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 12 - A Min.mid
# processing ../data/training_melody/ii-V3.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 5 - D Min.mid
# processing ../data/training_melody/lofitrack_12_melody.mid
# processing ../data/training_melody/tree5.mid
# processing ../data/training_melody/c13.mid
# processing ../data/training_melody/lofitrack_5_melody.mid
# processing ../data/training_melody/c12.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 17 - A# Maj.mid
# processing ../data/training_melody/tree4.mid
# processing ../data/training_melody/c1.mid
# processing ../data/training_melody/ii-V2.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 19 - A# Min.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 4 - D Maj.mid
# processing ../data/training_melody/ii-V6.mid
# processing ../data/training_melody/c5.mid
# processing ../data/training_melody/c16.mid
# processing ../data/training_melody/c17.mid
# processing ../data/training_melody/tree1.mid
# processing ../data/training_melody/Midi.mid
# processing ../data/training_melody/c4.mid
# processing ../data/training_melody/Loop 4 (Mantis).mid
# processing ../data/training_melody/ii-V7.mid
# processing ../data/training_melody/Cymatics - Eternity MIDI 16 - A# Maj.mid
# processing ../data/training_melody/ii-V5.mid
# processing ../data/training_melody/c6.mid
# processing ../data/training_melody/c15.mid
# processing ../data/training_melody/c29.mid
# processing ../data/training_melody/c28.mid
# processing ../data/training_melody/c14.mid
# processing ../data/training_melody/tree2.mid
# processing ../data/training_melody/c7.mid
# processing ../data/training_melody/ii-V4.mid

# %%
len(notes), len(set(notes))
# Out:
# (8839, 373)

# %% [markdown]
# # Model Training

# %%
""" Prepare the sequences used by the Neural Network """
sequence_length = 100
n_vocab = len(set(notes))

# get all pitch names
pitchnames = sorted(set(item for item in notes))

 # create a dictionary to map pitches to integers
note_to_int = dict((note, number) for number, note in enumerate(pitchnames))

network_input = []
network_output = []

# create input sequences and the corresponding outputs
for i in range(0, len(notes) - sequence_length, 1):
    sequence_in = notes[i:i + sequence_length]
    sequence_out = notes[i + sequence_length]
    network_input.append([note_to_int[char] for char in sequence_in])
    network_output.append(note_to_int[sequence_out])

n_patterns = len(network_input)

# reshape the input into a format compatible with LSTM layers
network_input = np.reshape(network_input, (n_patterns, sequence_length, 1))
# normalize input
network_input = network_input / float(n_vocab)

network_output = np_utils.to_categorical(network_output)

# %%
""" create the structure of the neural network """
model = Sequential()
model.add(LSTM(
    512,
    input_shape=(network_input.shape[1], network_input.shape[2]),
    recurrent_dropout=0.3,
    return_sequences=True
))
model.add(LSTM(512, return_sequences=True, recurrent_dropout=0.3,))
model.add(LSTM(512))
model.add(BatchNorm())
model.add(Dropout(0.3))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(BatchNorm())
model.add(Dropout(0.3))
model.add(Dense(n_vocab))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 512)          1052672
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100,
500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-76b472396d4c> in <module>
#      10 callbacks_list = [checkpoint]
#      11
# ---> 12 model.fit(network_input, network_output, epochs=500, batch_size=128, callbacks=callbacks_list)
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# ~/Library/Python/3.7/lib/python/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
""" Prepare the sequences used by the Neural Network """
# map between notes and integers and back
note_to_int = dict((note, number) for number, note in enumerate(pitchnames))

sequence_length = 100
network_input = []
output = []
for i in range(0, len(notes) - sequence_length, 1):
    sequence_in = notes[i:i + sequence_length]
    sequence_out = notes[i + sequence_length]
    network_input.append([note_to_int[char] for char in sequence_in])
    output.append(note_to_int[sequence_out])

n_patterns = len(network_input)

# reshape the input into a format compatible with LSTM layers
normalized_input = np.reshape(network_input, (n_patterns, sequence_length, 1))
# normalize input
normalized_input = normalized_input / float(n_vocab)

# %%
def generate_music_unconditional(gen_id, num_of_notes):
    """ Generate notes from the neural network based on a sequence of notes """
    
    # pick a random sequence from the input as a starting point for the prediction
    start = np.random.randint(0, len(network_input)-1)

    int_to_note = dict((number, note) for number, note in enumerate(pitchnames))

    pattern = network_input[start]
    prediction_output = []

    # generate `num_of_notes` notes
    for note_index in range(num_of_notes):
        prediction_input = np.reshape(pattern, (1, len(pattern), 1))
        prediction_input = prediction_input / float(n_vocab)

        prediction = model.predict(prediction_input, verbose=0)

        index = np.argmax(prediction)
        result = int_to_note[index]
        prediction_output.append(result)

        pattern.append(index)
        pattern = pattern[1:len(pattern)]
        
    """ convert the output from the prediction to notes and create a midi file
    from the notes """
    offset = 0
    output_notes = []

    # create note and chord objects based on the values generated by the model
    for pattern in prediction_output:
        # pattern is a chord
        if ('.' in pattern) or pattern.isdigit():
            notes_in_chord = pattern.split('.')
            notes = []
            for current_note in notes_in_chord:
                new_note = note.Note(int(current_note))
                new_note.storedInstrument = instrument.Piano()
                notes.append(new_note)
            new_chord = chord.Chord(notes)
            new_chord.offset = offset
            output_notes.append(new_chord)
        # pattern is a note
        else:
            new_note = note.Note(pattern)
            new_note.offset = offset
            new_note.storedInstrument = instrument.Piano()
            output_notes.append(new_note)

        # increase offset each iteration so that notes do not stack
        offset += 0.5

    output_path = f'generated_music/0719_brad/{gen_id}_output_{num_of_notes}_notes.mid'
    midi_stream = stream.Stream(output_notes)
    midi_stream.write('midi', fp=output_path)

# %% [markdown]
# # Generates Music

# %%
for i in range(2, 100):
    generate_music_unconditional(gen_id=i, num_of_notes=200)

# %% [markdown]
# ### This also lets you play around, embed it into `generate_music_unconditional`

# %%
output_notes
# Out:
# [<music21.note.Note B>,
#  <music21.chord.Chord E F>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.chord.Chord B D E G>,
#  <music21.note.Note B>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.chord.Chord E A>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note D>,
#  <music21.note.Note C>,
#  <music21.chord.Chord C# D E F# A>,
#  <music21.chord.Chord C# D E F# A>,
#  <music21.chord.Chord A C#>,
#  <music21.chord.Chord C# D E F#>,
#  <music21.note.Note E>,
#  <music21.chord.Chord F G# B C#>,
#  <music21.chord.Chord B C# E F>,
#  <music21.chord.Chord F B>,
#  <music21.note.Note G#>,
#  <music21.chord.Chord E F G# B>,
#  <music21.note.Note C#>,
#  <music21.chord.Chord B C# E F>,
#  <music21.note.Note G#>,
#  <music21.chord.Chord F G#>,
#  <music21.note.Note D>,
#  <music21.chord.Chord G# B C# E>,
#  <music21.chord.Chord C# E F# A>,
#  <music21.chord.Chord A C# E>,
#  <music21.chord.Chord C# E F#>,
#  <music21.chord.Chord C# E>,
#  <music21.chord.Chord C# E F# A>,
#  <music21.chord.Chord B D E G>,
#  <music21.chord.Chord G B>,
#  <music21.chord.Chord B D E G>,
#  <music21.note.Note B>,
#  <music21.chord.Chord B D E G>,
#  <music21.chord.Chord B D E>,
#  <music21.note.Note G>,
#  <music21.chord.Chord B D>,
#  <music21.chord.Chord D E G>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note C#>,
#  <music21.note.Note E>,
#  <music21.note.Note C#>,
#  <music21.chord.Chord C# D F# A>,
#  <music21.note.Note E>,
#  <music21.note.Note C#>,
#  <music21.chord.Chord A C#>,
#  <music21.chord.Chord D F#>,
#  <music21.chord.Chord B E>,
#  <music21.note.Note C#>,
#  <music21.chord.Chord B E>,
#  <music21.chord.Chord F B>,
#  <music21.chord.Chord G# C#>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.note.Note E>,
#  <music21.chord.Chord C# D E F>,
#  <music21.chord.Chord G# B>,
#  <music21.chord.Chord C# E F#>,
#  <music21.note.Note E>,
#  <music21.note.Note C#>,
#  <music21.chord.Chord C# E F# A>,
#  <music21.note.Note E>,
#  <music21.note.Note C#>,
#  <music21.chord.Chord E F#>,
#  <music21.chord.Chord A C#>,
#  <music21.chord.Chord B E>,
#  <music21.note.Note E>,
#  <music21.chord.Chord B E>,
#  <music21.chord.Chord E G>,
#  <music21.chord.Chord B E>,
#  <music21.chord.Chord B D>,
#  <music21.chord.Chord E>,
#  <music21.chord.Chord D E G A>,
#  <music21.note.Note C#>,
#  <music21.chord.Chord A C#>,
#  <music21.chord.Chord A D>,
#  <music21.chord.Chord E F# A>,
#  <music21.note.Note C#>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.chord.Chord B>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.chord.Chord C# E G#>,
#  <music21.note.Note E>,
#  <music21.chord.Chord E G# B>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.chord.Chord B D>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.chord.Chord C# E G#>,
#  <music21.note.Note E>,
#  <music21.chord.Chord E G# B>,
#  <music21.note.Note E>,
#  <music21.chord.Chord F G C>,
#  <music21.chord.Chord C D F>,
#  <music21.chord.Chord F A C>,
#  <music21.chord.Chord B->,
#  <music21.chord.Chord F A B- C>,
#  <music21.note.Note B->,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note B->,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.chord.Chord E G>,
#  <music21.chord.Chord F# A B>,
#  <music21.note.Note D>,
#  <music21.chord.Chord C# E>,
#  <music21.chord.Chord F# G B>,
#  <music21.note.Note G>,
#  <music21.chord.Chord A C D>,
#  <music21.chord.Chord E G B>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note F#>,
#  <music21.chord.Chord E G# B>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.chord.Chord G A>,
#  <music21.chord.Chord B C# F#>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note B>,
#  <music21.chord.Chord E- F#>,
#  <music21.chord.Chord F# A C#>,
#  <music21.note.Note E>,
#  <music21.note.Note D>,
#  <music21.note.Note C#>,
#  <music21.chord.Chord E G>,
#  <music21.chord.Chord F# A B>,
#  <music21.note.Note D>,
#  <music21.chord.Chord C# E>,
#  <music21.chord.Chord F# G B>,
#  <music21.note.Note G>,
#  <music21.chord.Chord A C D>,
#  <music21.chord.Chord E G B>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note F#>,
#  <music21.chord.Chord E G# B>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.chord.Chord G# A>,
#  <music21.chord.Chord B C# F#>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note F#>,
#  <music21.chord.Chord D F# A>,
#  <music21.note.Note C#>,
#  <music21.note.Note D>,
#  <music21.chord.Chord G B D>,
#  <music21.note.Note E>,
#  <music21.note.Note F#>,
#  <music21.note.Note G>,
#  <music21.chord.Chord C# E>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note C#>,
#  <music21.chord.Chord F# B>,
#  <music21.note.Note B>,
#  <music21.note.Note A>,
#  <music21.note.Note E->,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.note.Note E>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.note.Note A>,
#  <music21.note.Note C#>,
#  <music21.note.Note A>,
#  <music21.chord.Chord C# E G>,
#  <music21.note.Note B>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note C#>,
#  <music21.note.Note F#>,
#  <music21.note.Note B>,
#  <music21.chord.Chord A B>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.note.Note C#>,
#  <music21.chord.Chord E G>,
#  <music21.chord.Chord F# A B>,
#  <music21.note.Note D>,
#  <music21.chord.Chord C# E>,
#  <music21.chord.Chord F# G B>,
#  <music21.note.Note G>,
#  <music21.chord.Chord A C D>,
#  <music21.chord.Chord E G B>,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note F#>,
#  <music21.chord.Chord E G# B>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.chord.Chord G A>,
#  <music21.chord.Chord B C# F#>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note B>,
#  <music21.chord.Chord C# E- F# A>,
#  <music21.chord.Chord E G>,
#  <music21.chord.Chord F# A B>,
#  <music21.note.Note D>,
#  <music21.chord.Chord C# E>,
#  <music21.chord.Chord F# G B>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note F#>,
#  <music21.chord.Chord A C D>,
#  <music21.chord.Chord B D E G>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note F#>,
#  <music21.chord.Chord E G# B>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note B>,
#  <music21.chord.Chord G# A>,
#  <music21.chord.Chord B C# F#>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note D>,
#  <music21.note.Note F#>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note F#>,
#  <music21.chord.Chord A C# D>,
#  <music21.chord.Chord F G C>,
#  <music21.chord.Chord C D F>,
#  <music21.chord.Chord F A C>,
#  <music21.chord.Chord B->,
#  <music21.chord.Chord F A B- C>,
#  <music21.note.Note B->,
#  <music21.note.Note D>,
#  <music21.note.Note F>,
#  <music21.note.Note B->,
#  <music21.note.Note A>,
#  <music21.note.Note D>,
#  <music21.chord.Chord B D F#>,
#  <music21.chord.Chord G A D>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.note.Note D>,
#  <music21.note.Note C#>,
#  <music21.chord.Chord B D F#>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.chord.Chord F# A C#>,
#  <music21.chord.Chord E G A>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.chord.Chord F# A C#>,
#  <music21.chord.Chord D F# B->,
#  <music21.note.Note D>,
#  <music21.chord.Chord F# A C#>,
#  <music21.chord.Chord F# A B>,
#  <music21.note.Note A>,
#  <music21.chord.Chord C# F#>,
#  <music21.chord.Chord D F# A>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.note.Note F#>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.chord.Chord B D F#>,
#  <music21.chord.Chord G A D>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.note.Note D>,
#  <music21.note.Note C#>,
#  <music21.chord.Chord B D F#>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.chord.Chord F# A C#>,
#  <music21.chord.Chord E G A>,
#  <music21.note.Note E>,
#  <music21.note.Note A>,
#  <music21.chord.Chord F# A C#>,
#  <music21.chord.Chord D F# B->,
#  <music21.note.Note D>,
#  <music21.chord.Chord F# A C#>,
#  <music21.chord.Chord F# A B>,
#  <music21.note.Note A>,
#  <music21.chord.Chord C# F#>,
#  <music21.chord.Chord D F# A>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.chord.Chord C E- F#>,
#  <music21.chord.Chord F# B>,
#  <music21.note.Note G>,
#  <music21.note.Note A>,
#  <music21.chord.Chord F# G B D>,
#  <music21.chord.Chord B E>,
#  <music21.note.Note G>,
#  <music21.chord.Chord C E- F#>,
#  <music21.chord.Chord E- A>,
#  <music21.note.Note A>,
#  <music21.note.Note F#>,
#  <music21.chord.Chord C E- F#>,
#  <music21.chord.Chord F# A B>,
#  <music21.note.Note G>,
#  <music21.note.Note A>,
#  <music21.chord.Chord A B E>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.chord.Chord G B>,
#  <music21.note.Note G>,
#  <music21.note.Note F#>,
#  <music21.note.Note B->,
#  <music21.note.Note D>,
#  <music21.note.Note C#>,
#  <music21.chord.Chord C# E F#>,
#  <music21.chord.Chord C# D F#>,
#  <music21.chord.Chord F# A B>,
#  <music21.note.Note D>,
#  <music21.chord.Chord C# E G>,
#  <music21.chord.Chord G B- C#>,
#  <music21.note.Note E>,
#  <music21.chord.Chord C E F#>,
#  <music21.chord.Chord F# A C>,
#  <music21.note.Note F#>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note F#>,
#  <music21.chord.Chord F# G B>,
#  <music21.chord.Chord E G B>,
#  <music21.note.Note D>,
#  <music21.note.Note B>,
#  <music21.note.Note F#>,
#  <music21.note.Note G>,
#  <music21.chord.Chord A C E->,
#  <music21.chord.Chord F# A B>,
#  <music21.note.Note G>,
#  <music21.chord.Chord A C# E>,
#  <music21.chord.Chord E G B->,
#  <music21.note.Note G>,
#  <music21.chord.Chord F# G A B D>,
#  <music21.chord.Chord C E- F G G#>,
#  <music21.chord.Chord G B- C D E->,
#  <music21.chord.Chord E G A B C>,
#  <music21.chord.Chord G# C E->,
#  <music21.chord.Chord G G#>,
#  <music21.chord.Chord G G# B->,
#  <music21.chord.Chord F G G# C>,
#  <music21.note.Note E->,
#  <music21.chord.Chord B- C D E->,
#  <music21.chord.Chord G B- C D E->,
#  <music21.chord.Chord E G A B C>,
#  <music21.chord.Chord G G# B- C E->,
#  <music21.chord.Chord C E- F G G#>,
#  <music21.chord.Chord G B- C D E->,
#  <music21.chord.Chord E G A B C>,
#  <music21.chord.Chord G# C E->,
#  <music21.chord.Chord G G#>,
#  <music21.chord.Chord G G# B->,
#  <music21.chord.Chord F G G# C>,
#  <music21.note.Note E->,
#  <music21.chord.Chord B- C D E->,
#  <music21.chord.Chord G B- C D E->,
#  <music21.chord.Chord E G A B C>,
#  <music21.chord.Chord G G# B- C E->,
#  <music21.chord.Chord A B- D F>,
#  <music21.chord.Chord A B- D F>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.chord.Chord C E G>,
#  <music21.note.Note A>,
#  <music21.chord.Chord E G B- C>,
#  <music21.chord.Chord B- C F>,
#  <music21.chord.Chord E F G A C>,
#  <music21.chord.Chord E F A C>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.chord.Chord F G A C D>,
#  <music21.note.Note A>,
#  <music21.chord.Chord A C D F>,
#  <music21.note.Note F>,
#  <music21.note.Note G>,
#  <music21.chord.Chord D F A>,
#  <music21.chord.Chord A B- D F>,
#  <music21.chord.Chord A B- D F>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.chord.Chord E G B- C>,
#  <music21.note.Note A>,
#  <music21.chord.Chord E G B- C>,
#  <music21.chord.Chord B- C D F>,
#  <music21.chord.Chord E F A C>,
#  <music21.note.Note D>,
#  <music21.chord.Chord E F A C>,
#  <music21.note.Note D>,
#  <music21.chord.Chord C D E- F G>,
#  <music21.note.Note C>,
#  <music21.chord.Chord C E- F G>,
#  <music21.note.Note C>,
#  <music21.chord.Chord F G C>,
#  <music21.note.Note A>,
#  <music21.note.Note G>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note C>,
#  <music21.note.Note B>,
#  <music21.note.Note G>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note E>,
#  <music21.note.Note F>,
#  <music21.note.Note A>,
#  <music21.note.Note C>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note E>,
#  <music21.note.Note B>,
#  <music21.note.Note C>,
#  <music21.note.Note A>,
#  <music21.note.Note B>,
#  <music21.note.Note G#>,
#  <music21.note.Note C>,
#  <music21.note.Note D>,
#  <music21.note.Note D>,
#  <music21.note.Note E>,
#  <music21.note.Note F>,
#  <music21.note.Note F>,
#  <music21.note.Note D>]

# %%
midi_stream.show('midi')
# Out:
#                 <div id='midiPlayerDiv70279'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv70279');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
midi_stream.write('midi', fp='generated_music/0719_brad/0_output_500_notes.mid')
# Out:
# 'generated_music/0719_brad/0_output_500_notes.mid'
